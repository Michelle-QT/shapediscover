# %%
# for development
# %load_ext autoreload
# %autoreload 2

import numpy as np

from synthetic_data import sphere
from experiment_functions import test_correct_homology_quotient_all, get_correct_homology_quotient_all, correct_homology_quotient
from shapediscover import ShapeDiscover, shapediscover_plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
loss_weights = [1, 10, 1, 10]
knn = 30

# %%
twosphere_25_parameters = {
    "data_name": "twosphere",
    "X": sphere(2000, 2),
    "target_betti_numbers": [1, 0, 1],
    "target_recovery": 0.25,
    # shapediscover parameters
    "min_n_cover": 3,
    "max_n_cover": 10,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 5,
    "max_n_points_rips": 30,
    "min_n_points_sparserips": 5,
    "max_n_points_sparserips": 30,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 4,
    "max_n_points_witness": 25,
    # alpha parameters
    "min_n_points_alpha": 4,
    "max_n_points_alpha": 5,
}

twosphere_50_parameters = {
    "data_name": "twosphere",
    "X": sphere(2000, 2),
    "target_betti_numbers": [1, 0, 1],
    "target_recovery": 0.5,
    # shapediscover parameters
    "min_n_cover": 3,
    "max_n_cover": 10,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 20,
    "max_n_points_rips": 60,
    "min_n_points_sparserips": 20,
    "max_n_points_sparserips": 60,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 5,
    "max_n_points_witness": 50,
    # alpha parameters
    "min_n_points_alpha": 10,
    "max_n_points_alpha": 21,
}

threesphere_25_parameters = {
    "data_name": "threesphere",
    "X": sphere(2000, 3),
    "target_betti_numbers": [1, 0, 0, 1],
    "target_recovery": 0.25,
    # shapediscover parameters
    "min_n_cover": 3,
    "max_n_cover": 10,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 40,
    "max_n_points_rips": 50,
    "min_n_points_sparserips": 20,
    "max_n_points_sparserips": 60,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 5,
    "max_n_points_witness": 50,
    # alpha parameters
    "min_n_points_alpha": 10,
    "max_n_points_alpha": 41,
}

threesphere_50_parameters = {
    "data_name": "threesphere",
    "X": sphere(2000, 3),
    "target_betti_numbers": [1, 0, 0, 1],
    "target_recovery": 0.5,
    # shapediscover parameters
    "min_n_cover": 6,
    "max_n_cover": 30,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 150,
    "max_n_points_rips": 300,
    "min_n_points_sparserips": 150,
    "max_n_points_sparserips": 300,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 10,
    "max_n_points_witness": 200,
    # alpha parameters
    "min_n_points_alpha": 30,
    "max_n_points_alpha": 151,
}

human_01_parameters = {
    "data_name": "human",
    "X": np.loadtxt("datasets/human.txt"),
    "target_betti_numbers": [1, 0, 1],
    "target_recovery": 0.01,
    # shapediscover parameters
    "min_n_cover": 5,
    "max_n_cover": 21,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 50,
    "max_n_points_rips": 300,
    "min_n_points_sparserips": 50,
    "max_n_points_sparserips": 300,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 10,
    "max_n_points_witness": 80,
    # alpha parameters
    "min_n_points_alpha": 50,
    "max_n_points_alpha": 300,
}

human_05_parameters = {
    "data_name": "human",
    "X": np.loadtxt("datasets/human.txt"),
    "target_betti_numbers": [1, 0, 1],
    "target_recovery": 0.05,
    # shapediscover parameters
    "min_n_cover": 5,
    "max_n_cover": 21,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 100,
    "max_n_points_rips": 400,
    "min_n_points_sparserips": 100,
    "max_n_points_sparserips": 300,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 5,
    "max_n_points_witness": 80,
    # alpha parameters
    "min_n_points_alpha": 100,
    "max_n_points_alpha": 400,
}

dynamical_system_01_parameters = {
    "data_name": "dynamicalsystem",
    "X": np.load("datasets/dynamical_system_video.npy"),
    "target_betti_numbers": [1, 2, 1],
    "target_recovery": 0.01,
    # shapediscover parameters
    "min_n_cover": 10,
    "max_n_cover": 40,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 257,
    "max_n_points_rips": 300,
    "min_n_points_sparserips": 200,
    "max_n_points_sparserips": 300,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 59,
    "max_n_points_witness": 91,
    # alpha parameters
    "min_n_points_alpha": 257,
    "max_n_points_alpha": 300,
}

dynamical_system_05_parameters = {
    "data_name": "dynamicalsystem",
    "X": np.load("datasets/dynamical_system_video.npy"),
    "target_betti_numbers": [1, 2, 1],
    "target_recovery": 0.05,
    # shapediscover parameters
    "min_n_cover": 38,
    "max_n_cover": 60,
    "knn": knn,
    "loss_weights": loss_weights,
    # rips parameters
    "min_n_points_rips": 257,
    "max_n_points_rips": 300,
    "min_n_points_sparserips": 200,
    "max_n_points_sparserips": 300,
    # approximate rips parameter
    "approx_sparserips1": 0.5,
    "approx_sparserips2": 1,
    # witness parameter
    "min_n_points_witness": 50,
    "max_n_points_witness": 80,
    # alpha parameters
    "min_n_points_alpha": 257,
    "max_n_points_alpha": 300,
}

all_parameters = [
    twosphere_25_parameters,
    twosphere_50_parameters,
    threesphere_25_parameters,
    threesphere_50_parameters,
    #human_01_parameters,
    #human_05_parameters,
    #dynamical_system_01_parameters,
    #dynamical_system_05_parameters
]

# %%
for parameters in all_parameters:
    print("--------------------")
    test_correct_homology_quotient_all(**parameters, to_test=["shapediscover"])
# Out:
# --------------------
# twosphere 0.25
# shapediscover parameter 5
# shapediscover size 30
# --------------------
# twosphere 0.5
# shapediscover parameter 5
# shapediscover size 30
# --------------------
# threesphere 0.25
# shapediscover parameter 7
# shapediscover size 119
# --------------------
# threesphere 0.5
# shapediscover parameter 27
# shapediscover size 101583

# %%
twosphere_exp2_parameters = {
    "data_name": "twosphere",
    "X": sphere(2000, 2),
    "target_betti_numbers": [1, 0, 1],
    "n_vertices": 5,
    "knn": 15,
    "loss_weights": [1, 10, 1, 10],
}

threesphere_exp2_parameters = {
    "data_name": "threesphere",
    "X": sphere(2000, 3),
    "target_betti_numbers": [1, 0, 0, 1],
    "n_vertices": 19,
    "knn": 15,
    "loss_weights": [1, 10, 1, 10],
}

human_exp2_parameters = {
    "data_name": "human",
    "X": np.loadtxt("datasets/human.txt"),
    "target_betti_numbers": [1, 0, 1],
    "n_vertices": 19,
    "knn": 15,
    "loss_weights": [1, 10, 1, 10],
}

dynamical_exp2_parameters = {
    "data_name": "dynamicalsystem",
    "X": np.load("datasets/dynamical_system_video.npy"),
    "target_betti_numbers": [1, 2, 1],
    "n_vertices": 52, 
    "knn": 15,
    "loss_weights": [1, 10, 1, 10],
}

all_exp2_parameters = [
    twosphere_exp2_parameters,
    threesphere_exp2_parameters,
    human_exp2_parameters,
    dynamical_exp2_parameters,
]

# %%
for parameters in all_exp2_parameters:
    print("--------------------")
    get_correct_homology_quotient_all(**parameters)

# %%
from ripser import ripser
from persim import plot_diagrams

X = np.load("datasets/rat_brain/toremb_Y.npy")
print(X.shape)
dgms = ripser(X, n_perm=6000)['dgms']
print(correct_homology_quotient(dgms, [1,2]))

plot_diagrams(dgms, show=True)
# Out:
# (10000, 6)
# 0.0
